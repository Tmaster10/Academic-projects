# %% [markdown]
# # Canadian Airlines Ticket Price Analysis
#
#
# * Exploratory data analysis

# %% [markdown]
# We try to find and analyze those key factors like class of travel, duration of fight, etc. which helps us understand the pricing of tickets to plan and schedule our air travel in efficient way

# %% [markdown]
# ##### Import the required Python libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##### Reading the dataset using Pandas

# %%
df = pd.read_csv("Canadian_Airlines.csv")
df.head(30)
# Out:
#     Unnamed: 0          airline   Flight source_province departure_time Stops  \
# 0            0          WestJet  WJ-8709         Ontario        Evening  zero
# 1            1          WestJet  WJ-8157         Ontario  Early_Morning  zero
# 2            2      Air Transat   AT-764         Ontario  Early_Morning  zero
# 3            3   Flair Airlines   FA-995         Ontario        Morning  zero
# 4            4   Flair Airlines   FA-963         Ontario        Morning  zero
# 5            5   Flair Airlines   FA-945         Ontario        Morning  zero
# 6            6   Flair Airlines   FA-927         Ontario        Morning  zero
# 7            7   Flair Airlines   FA-951         Ontario      Afternoon  zero
# 8            8  Porter Airlines   P8-334         Ontario  Early_Morning  zero
# 9            9  Porter Airlines   P8-336         Ontario      Afternoon  zero
# 10          10  Porter Airlines   P8-392         Ontario      Afternoon  zero
# 11          11  Porter Airlines   P8-338         Ontario        Morning  zero
# 12          12        Air North  6A-5001         Ontario  Early_Morning  zero
# 13          13        Air North  6A-6202         Ontario        Morning  zero
# 14          14        Air North   6A-549         Ontario      Afternoon  zero
# 15          15        Air North  6A-6278         Ontario        Morning  zero
# 16          16       Air Canada   AC-887         Ontario  Early_Morning  zero
# 17          17       Air Canada   AC-665         Ontario  Early_Morning  zero
# 18          18      Air Transat   AT-747         Ontario        Evening   one
# 19          19      Air Transat   AT-747         Ontario        Evening   one
# 20          20  Porter Airlines   P8-266         Ontario  Early_Morning   one
# 21          21  Porter Airlines   P8-101         Ontario  Early_Morning   one
# 22          22  Porter Airlines   P8-103         Ontario        Evening   one
# 23          23       Air Canada   AC-441         Ontario        Evening   one
# 24          24        Air North  6A-5328         Ontario        Morning  zero
# 25          25   Flair Airlines   FA-933         Ontario      Afternoon  zero
# 26          26        Air North  6A-2046         Ontario        Evening  zero
# 27          27      Air Transat   AT-744         Ontario        Morning   one
# 28          28          WestJet  WJ-8169         Ontario        Evening  zero
# 29          29        Air North  6A-5041         Ontario        Evening  zero
#
#      arrival_time destination_province    class  duration  Days_left  price
# 0           Night               Quebec  Economy      2.17          1   5953
# 1         Morning               Quebec  Economy      2.33          1   5953
# 2   Early_Morning               Quebec  Economy      2.17          1   5956
# 3       Afternoon               Quebec  Economy      2.25          1   5955
# 4         Morning               Quebec  Economy      2.33          1   5955
# 5       Afternoon               Quebec  Economy      2.33          1   5955
# 6         Morning               Quebec  Economy      2.08          1   6060
# 7         Evening               Quebec  Economy      2.17          1   6060
# 8         Morning               Quebec  Economy      2.17          1   5954
# 9         Evening               Quebec  Economy      2.25          1   5954
# 10        Evening               Quebec  Economy      2.25          1   5954
# 11      Afternoon               Quebec  Economy      2.33          1   5954
# 12        Morning               Quebec  Economy      2.17          1   5955
# 13      Afternoon               Quebec  Economy      2.17          1   5955
# 14        Evening               Quebec  Economy      2.25          1   5955
# 15        Morning               Quebec  Economy      2.33          1   5955
# 16        Morning               Quebec  Economy      2.08          1   5955
# 17        Morning               Quebec  Economy      2.17          1   5955
# 18  Early_Morning               Quebec  Economy     12.25          1   5949
# 19        Morning               Quebec  Economy     16.33          1   5949
# 20        Evening               Quebec  Economy     11.75          1   5954
# 21          Night               Quebec  Economy     14.50          1   5954
# 22        Morning               Quebec  Economy     15.67          1   5954
# 23          Night               Quebec  Economy      3.75          1   5955
# 24        Morning               Quebec  Economy      2.50          1   6165
# 25        Evening               Quebec  Economy      2.17          1   6690
# 26        Evening               Quebec  Economy      2.17          1   6585
# 27      Afternoon               Quebec  Economy      5.83          1   8869
# 28          Night               Quebec  Economy      2.33          1  10260
# 29          Night               Quebec  Economy      2.17          1  10470

# %% [markdown]
# ##### About the dataset:
#
# The various features of the dataset are explained below:
# 1) Airline: The name of the airline company is stored in the airline column. It is a categorical feature having 6 different airlines.
# 2) Flight: Flight stores information regarding the plane's flight code. It is a categorical feature.
# 3) Source City: City from which the flight takes off. It is a categorical feature having 6 unique cities.
# 4) Departure Time: This is a derived categorical feature obtained created by grouping time periods into bins. It stores information about the departure time and have 6 unique time labels.
# 5) Stops: A categorical feature with 3 distinct values that stores the number of stops between the source and destination cities.
# 6) Arrival Time: This is a derived categorical feature created by grouping time intervals into bins. It has six distinct time labels and keeps information about the arrival time.
# 7) Destination City: City where the flight will land. It is a categorical feature having 6 unique cities.
# 8) Class: A categorical feature that contains information on seat class; it has two distinct values: Business and Economy.
# 9) Duration: A continuous feature that displays the overall amount of time it takes to travel between cities in hours.<br>
# 10)Days Left: This is a derived characteristic that is calculated by subtracting the trip date by the booking date.
# 11) Price: Target variable stores information of the ticket price.

# %%
df.nunique()
# Out:
# Unnamed: 0              300153
# airline                      6
# Flight                    1561
# source_province              6
# departure_time               6
# Stops                        3
# arrival_time                 6
# destination_province         6
# class                        2
# duration                   476
# Days_left                   49
# price                    12157
# dtype: int64

# %%
for col in df:
    if df[col].dtype == 'object':
        print(df[col].unique())
# Out:
# ['WestJet' 'Air Transat' 'Flair Airlines' 'Porter Airlines' 'Air North'
#  'Air Canada']
# ['WJ-8709' 'WJ-8157' 'AT-764' ... '6A-7127' '6A-7259' 'AC-433']
# ['Ontario' 'Quebec' 'Nova Scotia' 'Alberta' 'PEI'
#  'Newfoundland and Labrador']
# ['Evening' 'Early_Morning' 'Morning' 'Afternoon' 'Night' 'Late_Night']
# ['zero' 'one' 'two_or_more']
# ['Night' 'Morning' 'Early_Morning' 'Afternoon' 'Evening' 'Late_Night']
# ['Quebec' 'Nova Scotia' 'Alberta' 'PEI' 'Newfoundland and Labrador'
#  'Ontario']
# ['Economy' 'Business']

# %% [markdown]
# ##### About the columns:
#
# 1) In airline column there are 6 unique airlines: 'WestJet'& 'Air Transat'  & 'Flair Airlines' &'Porter Airlines' & 'Air North' & 'Air Canada'
# 2) In source_city & destination_city there are 6 unique Provinces: Ontario' & 'Quebec'& 'Nova Scotia'& 'Alberta' &'PEI' &'Newfoundland and Labrador
# 3) In arrival & departure columns there are 6 different timings: 'Evening'& 'Early_Morning'& 'Morning'& 'Afternoon' & 'Night'&  'Late_Night'
# 4) In class column there are 2 different classes: Economy &  Business

# %% [markdown]
# ### 3) Exploratory Data Analysis

# %%
from turtle import title
plt.figure(figsize=(15,5))
NF = sns.countplot(x='airline', data = df)
NF.set(xlabel='Airline in Canada', ylabel='No. of flights', title='No. of flight by Airlines')
plt.show(NF)

# %% [markdown]
# From the above figure, we can see 'Flair Airlines' has maximum no. of fights followed by 'Air Canada' while 'WestJet' has least no. of flights

# %%
from turtle import title
plt.figure(figsize=(15,5))
CE = sns.stripplot(x='price', y='class', data = df)
CE.set(xlabel='Ticket cost', ylabel='Class of Travel', title='Price range according to Class of Travel')
plt.show(CE)

# %% [markdown]
# From the above figure, we can see 'Economy' class tickets usually cost between 100 - 40100 while 'Business' class tickets usually cost between 15000 - 13000

# %%
from turtle import title
plt.figure(figsize=(15,5))
TA = sns.countplot(x='class', data = df)
TA.set(xlabel='Class of Travel', title='Availability of Tickets according to Class of Travel')
plt.show(TA)

# %% [markdown]
# From the above figure, we can see that availabilty of 'Economy' tickets is almost twice than availibitly of 'Business' class tickets which is explained by the fact that only 2 airlines - 'Air Canada, ir Airlines' offer 'Business' class tickets while all airlines offer 'Economy' class tickets.

# %%
plt.figure(figsize=(15,5))
AS = sns.barplot(x='airline', y='price', hue='class', data = df.sort_values('price'))
AS.set(xlabel='Airlines in Canada', ylabel='Price of Ticket', title='Economy Vs Business Ticket Prices by Airlines')
plt.show(AS)

# %% [markdown]
# From the above figure, we can conclude that 'Air Transat' offers the cheapest 'Economy' class tickets while 'Air North, 'Porter Airlines', 'Westjet' are almost similarly priced. Meanwhile 'Air Canada' and 'Flair Airlines' are priced much higher than other 4 airlines.
# 'Business' class tickets for 'Flair Airlines' cost much higher than 'Air Canada' which can be due to better service, quality of seats available.

# %%
df_temp = df.groupby(['Days_left'])['price'].mean().reset_index()
plt.figure(figsize=(15,5))
ax = plt.axes()
sns.regplot(x = df_temp.loc[df_temp['Days_left'] == 1].Days_left, y = df_temp.loc[df_temp['Days_left'] == 1].price, data= df_temp, fit_reg= False, ax=ax)
sns.regplot(x = df_temp.loc[(df_temp['Days_left'] > 1) & (df_temp['Days_left'] < 20)].Days_left, y = df_temp.loc[(df_temp['Days_left'] > 1) & (df_temp['Days_left'] < 20)].price, data = df_temp, fit_reg= True, ax=ax)
sns.regplot(x = df_temp.loc[df_temp['Days_left'] >= 20].Days_left, y = df_temp.loc[df_temp['Days_left'] >= 20].price, data = df_temp, fit_reg= True, ax=ax)
ax.set(xlabel='Tickets booked before X days', ylabel='Price of Ticket', title='Airline ticket prices based on days left before buying the ticket')
plt.show(ax)

# %% [markdown]
# From the above figure, we can conclude that ticket price rise slowly till 20 days from the date of flight, then rise sharply till the last day, while dramatically reducing just 1 day before the date of flight. This can be explained by the fact that people usually buy flight tickets within 2-3 weeks of flight which generates more profits for airlines. On last day, prices show dramatic reduction as airlines hope to fill the flight completely due to increase the load factor and decrease the operational cost per passenger.

# %% [markdown]
# ##### 6. How does price of ticket vary depending on duration of flight?

# %%
df_temp2 = df.groupby(['duration'])['price'].mean().reset_index()
plt.figure(figsize=(15,5))
PD = sns.scatterplot(x='duration', y='price', data = df_temp2)
PD = sns.regplot(x='duration', y='price', data = df_temp2, order = 2)
PD.set(xlabel='Duration of flight', ylabel='Price of Ticket', title='Average price depending on duration of flight')
plt.show(PD)

# %% [markdown]
# From the above figure, we can see that the relationship is not linear but can be approximated by second degree curve. We can see linear growth in prices as duration of flight increases till 20 and then lowering again.
# Some outliers may be affecting the curve.

# %% [markdown]
# ##### 7. How does ticket price vary according to departure time and arrival time?

# %%
plt.figure(figsize=(15,5))
plt.subplot (1,2,1)
sns.boxplot(data = df, x = 'departure_time', y = 'price', showfliers = False).set(xlabel = 'Departure Time', ylabel = 'Price of Ticket', title ='Price of Ticket depending on time of departure')
plt.subplot (1,2,2)
sns.boxplot(data = df, x = 'arrival_time', y = 'price', showfliers =  False).set(xlabel = 'Arrival Time', ylabel = 'Price of Ticket', title = 'Price of Ticket depending on time of arrival')
plt.show()

# %% [markdown]
# From the above figure, we can conclude that flights departing Late Night are cheapest while those arriving Eveving & Early Moring are cheap too. Flights departung in afternoon are relatively cheap as well.

# %%
ax = sns.relplot(x = 'destination_province', y = 'price', col='source_province', col_wrap= 3, kind= 'line', data = df)
ax.fig.subplots_adjust(top=0.9)
ax.fig.suptitle('Airline ticket prices based on the source and destination cities')
# Rotate x-axis labels for all subplots to avoid overlap
for a in ax.axes.flat:
    for label in a.get_xticklabels():
        label.set_rotation(45)
        label.set_horizontalalignment('right')
plt.show(ax)

# %% [markdown]
# From the above figure, we can conclude that flight departing from Ontario are usually cheaper. Nova Scotia-Newfoundland and Labrador seems to be the most expensive route to fly while Nova Scotia is most expensive city to fly.

# %%
fig, axs = plt.subplots(1,2, gridspec_kw= {'width_ratios': [3,1]}, figsize = (15,5))
sns.barplot(y = 'price', x = 'airline', hue = 'Stops', data = df.loc[df['class'] == 'Economy'].sort_values('price', ascending= False), ax = axs[0])
axs[0].set(xlabel='Airlines', ylabel='Price of Ticket', title='Price of Airline tickets based on No. of Stops in Economy Class')
sns.barplot(y='price', x='airline', hue='Stops', data= df.loc[df['class'] == 'Business'].sort_values('price', ascending= False), ax = axs[1])
axs[1].set(xlabel='Airlines', ylabel='Price of Ticket', title='Price of Airline tickets based on No. of Stops in Business Class')
plt.show(fig, axs)

# %% [markdown]
# From the above figure, we can conclude that Non-Stop flights are generally the cheapest while One-Stop flights are more expensive and 2+ stop flights are most expensive which can be explained on basis that as one undertakes more flights to fly to destination, it costs more.
# 'Air Transat' seems to be an exception in this case which shows little variation in prices between its Non-Stop, One Stop and 2+ Stop flights.
