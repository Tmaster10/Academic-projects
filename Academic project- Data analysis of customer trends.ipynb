# %%
print("hello")
# Out:
# hello

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('shopping_trends.csv')

# %%
import os
os.getcwd()
# Out:
# 'c:\\Durham College\\Lectures\\COSC-12001\\hands-on'

# %%
# to see first 5 rows
df.head(5)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.tail(5)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                     28    Virginia    L  Turquoise  Summer
# 3896                     49        Iowa    L      White  Spring
# 3897                     33  New Jersey    L      Green  Spring
# 3898                     77   Minnesota    S      Brown  Summer
# 3899                     81  California    M      Beige  Spring
#
#       Review Rating Subscription Status Payment Method   Shipping Type  \
# 3895            4.2                  No           Cash  2-Day Shipping
# 3896            4.5                  No         PayPal    Store Pickup
# ...

# %%
df.iloc[:3]
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
#
#         Location Size   Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L    Gray  Winter            3.1                 Yes
# 1          Maine    L  Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S  Maroon  Spring            3.1                 Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card        Express              Yes             Yes
# 1  Bank Transfer        Express              Yes             Yes
# 2           Cash  Free Shipping              Yes             Yes
#
#    Previous Purchases Preferred Payment Method Frequency of Purchases
# ...

# %%
x = np.array([1,2,3,4])
x
# Out:
# array([1, 2, 3, 4])

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df['Age']
# Out:
# 0       55
# 1       19
# 2       50
# 3       21
# 4       45
#         ..
# 3895    40
# 3896    52
# 3897    46
# 3898    44
# 3899    52
# Name: Age, Length: 3900, dtype: int64

# %%
df.dtypes
# Out:
# Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
df.head(5)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.iloc[3]['Customer ID'] = -4
# Out:
# C:\Users\100506079\AppData\Local\Temp\ipykernel_15752\1136541703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[3]['Customer ID'] = -4

# %%
df.loc[3,'Customer ID']  = np.NAN

# %%
df.head(5)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0          1.0   55   Male         Blouse  Clothing                     53
# 1          2.0   19   Male        Sweater  Clothing                     64
# 2          3.0   50   Male          Jeans  Clothing                     73
# 3          NaN   21   Male        Sandals  Footwear                     90
# 4          5.0   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                 1
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
df.dropna()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0             1.0   55    Male         Blouse     Clothing
# 1             2.0   19    Male        Sweater     Clothing
# 2             3.0   50    Male          Jeans     Clothing
# 4             5.0   45    Male         Blouse     Clothing
# 5             6.0   46    Male       Sneakers     Footwear
# ...           ...  ...     ...            ...          ...
# 3895       3896.0   40  Female         Hoodie     Clothing
# 3896       3897.0   52  Female       Backpack  Accessories
# 3897       3898.0   46  Female           Belt  Accessories
# 3898       3899.0   44  Female          Shoes     Footwear
# 3899       3900.0   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                 1
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0          1.0   55   Male         Blouse  Clothing                     53
# 1          2.0   19   Male        Sweater  Clothing                     64
# 2          3.0   50   Male          Jeans  Clothing                     73
# 3          NaN   21   Male        Sandals  Footwear                     90
# 4          5.0   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.dropna(inplace=True)
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0          1.0   55   Male         Blouse  Clothing                     53
# 1          2.0   19   Male        Sweater  Clothing                     64
# 2          3.0   50   Male          Jeans  Clothing                     73
# 4          5.0   45   Male         Blouse  Clothing                     49
# 5          6.0   46   Male       Sneakers  Footwear                     20
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
# 5        Wyoming    M      White  Summer            2.9                 Yes
#
# ...

# %%
df.drop(columns=['Customer ID'])
# Out:
#       Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0      55    Male         Blouse     Clothing                     53
# 1      19    Male        Sweater     Clothing                     64
# 2      50    Male          Jeans     Clothing                     73
# 4      45    Male         Blouse     Clothing                     49
# 5      46    Male       Sneakers     Footwear                     20
# ...   ...     ...            ...          ...                    ...
# 3895   40  Female         Hoodie     Clothing                     28
# 3896   52  Female       Backpack  Accessories                     49
# 3897   46  Female           Belt  Accessories                     33
# 3898   44  Female          Shoes     Footwear                     77
# 3899   52  Female        Handbag  Accessories                     81
#
#            Location Size      Color  Season  Review Rating  \
# 0          Kentucky    L       Gray  Winter            3.1
# ...

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0          1.0   55   Male         Blouse  Clothing                     53
# 1          2.0   19   Male        Sweater  Clothing                     64
# 2          3.0   50   Male          Jeans  Clothing                     73
# 4          5.0   45   Male         Blouse  Clothing                     49
# 5          6.0   46   Male       Sneakers  Footwear                     20
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
# 5        Wyoming    M      White  Summer            2.9                 Yes
#
# ...

# %%
df.drop(columns=['Customer ID'], inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Item Purchased', 'Category', 'Purchase Amount (USD)',
#        'Location', 'Size', 'Color', 'Season', 'Review Rating',
#        'Subscription Status', 'Payment Method', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Preferred Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.iloc[5] = df.iloc[6]

# %%
df.head(7)
# Out:
#    Age Gender Item Purchased  Category  Purchase Amount (USD)       Location  \
# 0   55   Male         Blouse  Clothing                     53       Kentucky
# 1   19   Male        Sweater  Clothing                     64          Maine
# 2   50   Male          Jeans  Clothing                     73  Massachusetts
# 4   45   Male         Blouse  Clothing                     49         Oregon
# 5   46   Male       Sneakers  Footwear                     20        Wyoming
# 6   27   Male         Shorts  Clothing                     34      Louisiana
# 7   27   Male         Shorts  Clothing                     34      Louisiana
#
#   Size      Color  Season  Review Rating Subscription Status Payment Method  \
# 0    L       Gray  Winter            3.1                 Yes    Credit Card
# 1    L     Maroon  Winter            3.1                 Yes  Bank Transfer
# 2    S     Maroon  Spring            3.1                 Yes           Cash
# ...

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 4       False
# 5       False
#         ...
# 3895    False
# 3896    False
# 3897    False
# 3898    False
# 3899    False
# Length: 3899, dtype: bool

# %%
df[df.duplicated()]
# Out:
#    Age Gender Item Purchased  Category  Purchase Amount (USD)   Location Size  \
# 7   27   Male         Shorts  Clothing                     34  Louisiana    L
#
#       Color  Season  Review Rating Subscription Status Payment Method  \
# 7  Charcoal  Winter            3.2                 Yes     Debit Card
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 7  Free Shipping              Yes             Yes                  19
#
#   Preferred Payment Method Frequency of Purchases
# 7              Credit Card                 Weekly

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(10)
# Out:
#     Age Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0    55   Male         Blouse     Clothing                     53
# 1    19   Male        Sweater     Clothing                     64
# 2    50   Male          Jeans     Clothing                     73
# 4    45   Male         Blouse     Clothing                     49
# 5    46   Male       Sneakers     Footwear                     20
# 6    27   Male         Shorts     Clothing                     34
# 8    26   Male           Coat    Outerwear                     97
# 9    57   Male        Handbag  Accessories                     31
# 10   53   Male          Shoes     Footwear                     34
# 11   30   Male         Shorts     Clothing                     68
#
#          Location Size      Color  Season  Review Rating Subscription Status  \
# 0        Kentucky    L       Gray  Winter            3.1                 Yes
# 1           Maine    L     Maroon  Winter            3.1                 Yes
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      2650
# Female    1248
# Name: count, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      2650
# Female    1248
# Name: count, dtype: int64

# %%
df.Color.value_counts()
# Out:
# Color
# Olive        177
# Yellow       174
# Silver       173
# Teal         172
# Green        169
# Black        167
# Cyan         166
# Violet       166
# Gray         158
# Maroon       157
# Orange       154
# Charcoal     153
# Pink         153
# Magenta      152
# Blue         152
# Purple       151
# Peach        149
# Red          148
# Beige        147
# Indigo       147
# Lavender     147
# Turquoise    145
# White        142
# Brown        141
# Gold         138
# Name: count, dtype: int64

# %%
type(df.Color.value_counts())
# Out:
# pandas.core.series.Series

# %%
df.Color.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Color'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Purchase Amount (USD)'}>],
#        [<Axes: title={'center': 'Review Rating'}>,
#         <Axes: title={'center': 'Previous Purchases'}>]], dtype=object)

# %%
df.Color.hist()
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Age Gender Item Purchased  Category  Purchase Amount (USD)       Location  \
# 0   55   Male         Blouse  Clothing                     53       Kentucky
# 1   19   Male        Sweater  Clothing                     64          Maine
# 2   50   Male          Jeans  Clothing                     73  Massachusetts
# 4   45   Male         Blouse  Clothing                     49         Oregon
# 5   46   Male       Sneakers  Footwear                     20        Wyoming
#
#   Size      Color  Season  Review Rating Subscription Status Payment Method  \
# 0    L       Gray  Winter            3.1                 Yes    Credit Card
# 1    L     Maroon  Winter            3.1                 Yes  Bank Transfer
# 2    S     Maroon  Spring            3.1                 Yes           Cash
# 4    M  Turquoise  Spring            2.7                 Yes           Cash
# 5    M      White  Summer            2.9                 Yes          Venmo
#
# ...

# %%
df.dtypes
# Out:
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['Gender', 'Item Purchased', 'Category', 'Location', 'Size', 'Color',
#        'Season', 'Subscription Status', 'Payment Method', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.select_dtypes(include=['float64', 'int64']).columns
# Out:
# Index(['Age', 'Purchase Amount (USD)', 'Review Rating', 'Previous Purchases'], dtype='object')

# %%
df.Color.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df.dtypes
# Out:
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
df.boxplot(column=['Age'])
# Out:
# <Axes: >

# %%
df['Age'].describe()
# Out:
# count    3898.000000
# mean       44.069523
# std        15.203978
# min        18.000000
# 25%        31.000000
# 50%        44.000000
# 75%        57.000000
# max        70.000000
# Name: Age, dtype: float64

# %%
df.loc[25,'Age'] = 120

# %%
df['Age'].describe()
# Out:
# count    3898.000000
# mean       44.095690
# std        15.246813
# min        18.000000
# 25%        31.000000
# 50%        44.000000
# 75%        57.000000
# max       120.000000
# Name: Age, dtype: float64

# %%
df.boxplot(column=['Age'])
# Out:
# <Axes: >

# %%
df.Age.describe()
# Out:
# count    3898.000000
# mean       44.095690
# std        15.246813
# min        18.000000
# 25%        31.000000
# 50%        44.000000
# 75%        57.000000
# max       120.000000
# Name: Age, dtype: float64

# %%
q1 = df.Age.quantile(0.25)
q3 = df.Age.quantile(0.75)
IQR = q3 - q1
upper = q3 +1.5*IQR
lower = q1 - 1.5*IQR
(upper , lower)
# Out:
# (96.0, -8.0)

# %%
df[df.Age > upper]
# Out:
#     Age Gender Item Purchased  Category  Purchase Amount (USD) Location Size  \
# 25  120   Male         Hoodie  Clothing                     25    Texas    M
#
#      Color  Season  Review Rating Subscription Status Payment Method  \
# 25  Silver  Summer            3.6                 Yes  Bank Transfer
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 25       Express              Yes             Yes                  14
#
#    Preferred Payment Method Frequency of Purchases
# 25                   PayPal               Annually

# %%
df[df.Age > upper]
# Out:
#     Age Gender Item Purchased  Category  Purchase Amount (USD) Location Size  \
# 25  120   Male         Hoodie  Clothing                     25    Texas    M
#
#      Color  Season  Review Rating Subscription Status Payment Method  \
# 25  Silver  Summer            3.6                 Yes  Bank Transfer
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 25       Express              Yes             Yes                  14
#
#    Preferred Payment Method Frequency of Purchases
# 25                   PayPal               Annually

# %%
drop_index = df[df.Age > upper].index

df.drop(drop_index, inplace=True)

# %%
df.boxplot(column=['Age'])
# Out:
# <Axes: >

# %%
import pandas as pd

# %%
df = pd.read_csv('shopping_trends.csv')

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
categorical_columns, numerical_columns
# Out:
# (Index(['Gender', 'Item Purchased', 'Category', 'Location', 'Size', 'Color',
#         'Season', 'Subscription Status', 'Payment Method', 'Shipping Type',
#         'Discount Applied', 'Promo Code Used', 'Preferred Payment Method',
#         'Frequency of Purchases'],
#        dtype='object'),
#  Index(['Customer ID', 'Age', 'Purchase Amount (USD)', 'Review Rating',
#         'Previous Purchases'],
#        dtype='object'))

# %%
df = df.drop(columns=['Customer ID'])
df.head()
# Out:
#    Age Gender Item Purchased  Category  Purchase Amount (USD)       Location  \
# 0   55   Male         Blouse  Clothing                     53       Kentucky
# 1   19   Male        Sweater  Clothing                     64          Maine
# 2   50   Male          Jeans  Clothing                     73  Massachusetts
# 3   21   Male        Sandals  Footwear                     90   Rhode Island
# 4   45   Male         Blouse  Clothing                     49         Oregon
#
#   Size      Color  Season  Review Rating Subscription Status Payment Method  \
# 0    L       Gray  Winter            3.1                 Yes    Credit Card
# 1    L     Maroon  Winter            3.1                 Yes  Bank Transfer
# 2    S     Maroon  Spring            3.1                 Yes           Cash
# 3    M     Maroon  Spring            3.5                 Yes         PayPal
# 4    M  Turquoise  Spring            2.7                 Yes           Cash
#
# ...

# %%
df.head()
# Out:
#    Age Gender Item Purchased  Category  Purchase Amount (USD)       Location  \
# 0   55   Male         Blouse  Clothing                     53       Kentucky
# 1   19   Male        Sweater  Clothing                     64          Maine
# 2   50   Male          Jeans  Clothing                     73  Massachusetts
# 3   21   Male        Sandals  Footwear                     90   Rhode Island
# 4   45   Male         Blouse  Clothing                     49         Oregon
#
#   Size      Color  Season  Review Rating Subscription Status Payment Method  \
# 0    L       Gray  Winter            3.1                 Yes    Credit Card
# 1    L     Maroon  Winter            3.1                 Yes  Bank Transfer
# 2    S     Maroon  Spring            3.1                 Yes           Cash
# 3    M     Maroon  Spring            3.5                 Yes         PayPal
# 4    M  Turquoise  Spring            2.7                 Yes           Cash
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.displot(data=tips, x = 'total_bill', hue = 'time')

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='swarm')

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='violin', hue='smoker', split=True)

# %%
sns.displot(data=tips, x='total_bill')

# %%
import pandas as pd

# Assuming df is your DataFrame
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns

print("Numerical columns:", numerical_cols)
print("Categorical columns:", categorical_cols)
# Out:
# Numerical columns: Index(['Age', 'Purchase Amount (USD)', 'Review Rating', 'Previous Purchases'], dtype='object')
# Categorical columns: Index(['Gender', 'Item Purchased', 'Category', 'Location', 'Size', 'Color',
#        'Season', 'Subscription Status', 'Payment Method', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
sns.heatmap(df[numerical_columns].corr(), annot=True, cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 sns.heatmap(df[numerical_columns].corr(), annot=True, cmap='coolwarm')
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %%
df.head()
# Out:
#    Age Gender Item Purchased  Category  Purchase Amount (USD)       Location  \
# 0   55   Male         Blouse  Clothing                     53       Kentucky
# 1   19   Male        Sweater  Clothing                     64          Maine
# 2   50   Male          Jeans  Clothing                     73  Massachusetts
# 3   21   Male        Sandals  Footwear                     90   Rhode Island
# 4   45   Male         Blouse  Clothing                     49         Oregon
#
#   Size      Color  Season  Review Rating Subscription Status Payment Method  \
# 0    L       Gray  Winter            3.1                 Yes    Credit Card
# 1    L     Maroon  Winter            3.1                 Yes  Bank Transfer
# 2    S     Maroon  Spring            3.1                 Yes           Cash
# 3    M     Maroon  Spring            3.5                 Yes         PayPal
# 4    M  Turquoise  Spring            2.7                 Yes           Cash
#
# ...

# %%
dummy = pd.DataFrame({'car': ['toyota', 'honda', 'ford', 'kia']})
dummy
# Out:
#       car
# 0  toyota
# 1   honda
# 2    ford
# 3     kia

# %%
dummy.dtypes
# Out:
# car    object
# dtype: object

# %%
dummy['car'] = dummy['car'].astype('category')

# %%
dummy.dtypes
# Out:
# car    category
# dtype: object

# %%
dummy['car'].cat.codes
# Out:
# 0    3
# 1    1
# 2    0
# 3    2
# dtype: int8

# %%
dummy['car_codes'] = dummy['car'].cat.codes
dummy
# Out:
#       car  car_codes
# 0  toyota          3
# 1   honda          1
# 2    ford          0
# 3     kia          2

# %%
dummy = pd.DataFrame({'car': ['toyota', 'honda', 'ford', 'kia']})

# %%
dummy
# Out:
#       car
# 0  toyota
# 1   honda
# 2    ford
# 3     kia
